# %% [markdown]
# # Search for R-Packages

# %% [markdown]
# - Resource 1
# https://www.r-pkg.org/
# - Resource 2
# https://cran.r-project.org/web/packages/available_packages_by_name.html
# - Resource 3
# https://rdrr.io/find/?repos=cran%2Cbioc%2Crforge%2Cgithub&page=0&fuzzy_slug=

# %% [markdown]
# # 1. DPLYR

# %%
#Step 1
install.packages('dplyr')
#Step 2
library(dplyr)

# %% [markdown]
# # 2. Italian household survey data

# %%
install.packages("italy")
library(italy)

# %% [markdown]
# ## 2.1 Check information on the package

# %%
??italy

# %% [markdown]
# ## 2.2 Show data

# %%
## 1.2 Inspect data
italy08 %>% 
  head(10)

# %%
italy10 %>% 
  head(10)

# %% [markdown]
# # 3. 2017-18 Household Questionnaire Data for Punjab, Pakistan

# %% [markdown]
# ## 3.1 Install

# %%
install.packages('PakPMICS2018hh')
library(PakPMICS2018hh)

# %% [markdown]
# ## 3.2 Package details

# %%
??PakPMICS2018hh

# %%
## 2.3 Load package
PakPMICS2018hh

# %% [markdown]
# # 4. Povcalnet
# ### Examples: https://rdrr.io/cran/povcalnetR/f/vignettes/povcalnetR.Rmd

# %%
install.packages('povcalnetR')
library(povcalnetR)

# %%
china_df = povcalnet(country = c("CHN"))

# %% [markdown]
# # 5. Worldbank

# %%
#install.packages('WDI')

library(WDI)

# %% [markdown]
# ## 4.1 Search for data

# %%
search_df = WDIsearch(string = "gender", field = "name") %>% as_tibble()

# %% [markdown]
# ## 4.2 Download data

# %%
wdi_df = WDI(indicator = "5.51.01.07.gender", country= c('AF'), start=2000)

# %% [markdown]
# # 5. Search github!
# https://github.com/search?p=3&q=Household+Survey&type=Repositories
